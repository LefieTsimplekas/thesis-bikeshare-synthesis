# %%
import pandas as pd
from pandas import read_parquet
df = read_parquet(r"C:\Users\lefte\Desktop\GitHub Projects\Thesis_project\data\processed\final_training_dataset_with_weather.parquet")
df.head()
# Out:
#   rideable_type              started_at member_casual     city  trip_duration  \
# 0  classic_bike 2025-01-18 15:59:26.296        casual  chicago      63.633333
# 1  classic_bike 2025-01-04 15:50:40.398        casual  chicago       8.350000
# 2  classic_bike 2025-01-05 14:07:30.549        casual  chicago       7.366667
# 3  classic_bike 2025-01-04 15:34:02.555        casual  chicago       1.433333
# 4  classic_bike 2025-01-26 15:02:25.915        casual  chicago       1.466667
#
#    same_station  day_of_week  month  is_weekend part_of_day  ...  \
# 0             0            5      1           1      midday  ...
# 1             0            5      1           1      midday  ...
# 2             0            6      1           1      midday  ...
# 3             1            5      1           1      midday  ...
# 4             1            6      1           1      midday  ...
#
#    haversine_distance_km  bearing_sin  bearing_cos  hour  temperature_c  \
# ...

# %%
df.columns
# Out:
# Index(['rideable_type', 'started_at', 'member_casual', 'city', 'trip_duration',
#        'same_station', 'day_of_week', 'month', 'is_weekend', 'part_of_day',
#        'hour_sin', 'hour_cos', 'haversine_distance_km', 'bearing_sin',
#        'bearing_cos', 'hour', 'temperature_c', 'precipitation_mm',
#        'wind_speed_kph', 'snow_mm', 'rain_flag', 'snow_flag'],
#       dtype='object')

# %%
df2 = read_parquet(r"C:\Users\lefte\Desktop\GitHub Projects\Thesis_project\data\processed\london_featured_with_weather.parquet")
df2.head()
# Out:
#    rideable_type          started_at member_casual    city  trip_duration  \
# 0   classic_bike 2025-01-14 23:59:00       unknown  london      14.507800
# 1   classic_bike 2025-01-14 23:59:00       unknown  london       5.119683
# 2   classic_bike 2025-01-14 23:59:00       unknown  london      10.679250
# 3   classic_bike 2025-01-14 23:59:00       unknown  london      10.709133
# 4  electric_bike 2025-01-14 23:58:00       unknown  london      15.736417
#
#    same_station  hour  day_of_week  month  is_weekend  ...  \
# 0             0    23            1      1           0  ...
# 1             0    23            1      1           0  ...
# 2             0    23            1      1           0  ...
# 3             0    23            1      1           0  ...
# 4             0    23            1      1           0  ...
#
#   haversine_distance_km     bearing  bearing_sin  bearing_cos  temperature_c  \
# 0              2.843154  104.199923     0.969446    -0.245306            7.1
# ...

# %%
df.columns
# Out:
# Index(['rideable_type', 'started_at', 'member_casual', 'city', 'trip_duration',
#        'same_station', 'day_of_week', 'month', 'is_weekend', 'part_of_day',
#        'hour_sin', 'hour_cos', 'haversine_distance_km', 'bearing_sin',
#        'bearing_cos', 'hour', 'temperature_c', 'precipitation_mm',
#        'wind_speed_kph', 'snow_mm', 'rain_flag', 'snow_flag'],
#       dtype='object')

# %%
df2.columns
# Out:
# Index(['rideable_type', 'started_at', 'member_casual', 'city', 'trip_duration',
#        'same_station', 'hour', 'day_of_week', 'month', 'is_weekend',
#        'part_of_day', 'hour_sin', 'hour_cos', 'delta_lat', 'delta_lng',
#        'haversine_distance_km', 'bearing', 'bearing_sin', 'bearing_cos',
#        'temperature_c', 'precipitation_mm', 'wind_speed_kph', 'snow_mm',
#        'rain_flag', 'snow_flag'],
#       dtype='object')
